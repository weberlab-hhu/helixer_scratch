# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df_aug = pd.read_csv('animal_LSTM_eval - Augustus_all.csv')
df_ZCPHo_6 = pd.read_csv('animal_LSTM_eval - ZCPHo_6_flexible_overlapping.csv')

# %%
df_aug
# Out:
#                       genome  acc_overall   f1_ig  f1_utr  f1_exon  f1_intron  \
# 0     ailuropoda_melanoleuca       0.7989  0.8520  0.0000   0.7624     0.6904
# 1    amphilophus_citrinellus       0.7536  0.6603  0.0000   0.8290     0.7962
# 2       amphiprion_ocellaris       0.8144  0.8693  0.0010   0.7712     0.7184
# 3         amphiprion_percula       0.7911  0.8462  0.0000   0.7501     0.7105
# 4         anabas_testudineus       0.7976  0.8491  0.0000   0.8207     0.7304
# ..                       ...          ...     ...     ...      ...        ...
# 178            vulpes_vulpes       0.8370  0.8989  0.0004   0.6784     0.6034
# 179       xenopus_tropicalis       0.7969  0.8720  0.0059   0.5613     0.5975
# 180   xiphophorus_couchianus       0.6962  0.3076  0.0000   0.8337     0.7861
# 181    xiphophorus_maculatus       0.7631  0.8263  0.0000   0.7533     0.6678
# 182   zonotrichia_albicollis       0.8332  0.8950  0.0037   0.7906     0.6140
#
# ...
